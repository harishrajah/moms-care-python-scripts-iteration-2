# %% [markdown]
# Environment: Python 3.6.4 and Jupyter notebook
#
# Libraries Used :
# * pandas (for dataframe, included in Anaconda Python 3.6.4)
# * re (for regular expression, included in Anaconda Python 3.6.4)
# * numpy (for numpy array, included in Anaconda Python 3.6.4)

# %% [markdown]
# ## 1.  Import libraries

# %%
# Importing necessary packages
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. Parse CSV File

# %%
# Loading the hospital_locations csv file
csv_file = pd.read_csv('Hospital_Locations.csv')


# dropping the unrequired columns
csv_file = csv_file.drop(['FID', 'OpsName','Type', 'RoadSuffix', 'CampusCode','VicgovRegi','ServiceNam'], axis=1)


# Renaming columns
csv_file.columns = ['long', 'lat', 'Hospital', 'Street Number', 'Road Name', 'Road Type','LGAName','Suburb', 'postcode', 'State']
#lat, long, postcode, name, address
# Deleting the record which does not belongs to VIC state
csv_file = csv_file[csv_file.State != 'NSW']

# printing first 2o rows
csv_file.head(20)
# Out:
#           long        lat                                     Hospital  \
# 0   144.983399 -37.809681       East Melbourne Specialist Day Hospital
# 1   145.149300 -37.951400                   Windsor Avenue Day Surgery
# 2   145.344653 -38.034580       Hyperbaric Health Wound Centre Berwick
# 3   143.832286 -37.540553                Ballarat Day Procedure Centre
# 4   145.143379 -38.148189  Bayside Day Procedure and Specialist Centre
# 5   144.261500 -36.761900                          Bendigo Day Surgery
# 6   145.041233 -37.920125                        Bentleigh Surgicentre
# 7   145.346519 -38.033496                          Berwick Surgicentre
# 8   144.991817 -37.912560              Brighton Plastic Surgery Centre
# 9   145.061879 -37.692573                         Victorian Gut Centre
# 10  145.056802 -37.960467                    Chesterville Day Hospital
# 11  144.964771 -37.745017                      Coburg Endoscopy Centre
# 12  145.223301 -37.974247    Dandenong Eye Clinic & Day Surgery Centre
# 13  145.017576 -37.781101                   Darebin Endoscopy Services
# 14  145.107588 -37.705329      Diaverum Diamond Valley Dialysis Clinic
# 15  144.939908 -37.788679     Diaverum North Melbourne Dialysis Clinic
# 16  145.227502 -37.819784                    Eastside Endoscopy Centre
# 17  144.923638 -37.765793                      Essendon Private Clinic
# 18  145.019214 -37.900435                        Glen Eira Day Surgery
# 19  145.094026 -37.858089                            Glen Iris Private
#
#    Street Number        Road Name Road Type            LGAName Suburb  \
# 0             23        CLARENDON    STREET          MELBOURNE
# 1             17          WINDSOR    AVENUE  GREATER DANDENONG
# 2              3             GIBB    STREET              CASEY
# 3      1117-1123           HOWITT    STREET           BALLARAT
# 4            141       CRANBOURNE      ROAD          FRANKSTON
# 5            1-7             CHUM    STREET    GREATER BENDIGO
# 6            157           JASPER      ROAD          GLEN EIRA
# 7             22         LANGMORE      LANE              CASEY
# 8            206              NEW    STREET            BAYSIDE
# 9            119           PLENTY      ROAD         WHITTLESEA
# 10            28     CHESTERVILLE      ROAD           KINGSTON
# 11            15            MUNRO    STREET           MORELAND
# 12           1-3         FALKINER  CRESCENT  GREATER DANDENONG
# 13            42          STATION    STREET            DAREBIN
# 14            15         GRIMSHAW    STREET            BANYULE
# 15           185         BOUNDARY      ROAD          MELBOURNE
# 16            33         WANTIRNA      ROAD          MAROONDAH
# 17           665  MOUNT ALEXANDER      ROAD      MOONEE VALLEY
# 18           544         HAWTHORN      ROAD          GLEN EIRA
# 19           314         WARRIGAL      ROAD         BOROONDARA
#
#     postcode State
# 0       3002   VIC
# 1       3171   VIC
# 2       3806   VIC
# 3       3355   VIC
# 4       3199   VIC
# 5       3555   VIC
# 6       3204   VIC
# 7       3806   VIC
# 8       3186   VIC
# 9       3083   VIC
# 10      3192   VIC
# 11      3058   VIC
# 12      3175   VIC
# 13      3078   VIC
# 14      3088   VIC
# 15      3051   VIC
# 16      3134   VIC
# 17      3039   VIC
# 18      3162   VIC
# 19      3146   VIC

# %%
#Eliminating strings like within braces and comma in the hospital column and storing the required information in the hospital name column

csv_file['name'] = csv_file['Hospital'].str.split(',').str[0]
csv_file['name'] = csv_file['name'].str.split('(').str[0]
csv_file = csv_file.drop('Hospital', axis=1)

# %%
# checking the unique values in suburb column
csv_file['Suburb'].unique()


# replacing the '' to 'A' first and then 'A' to nan values
csv_file['Suburb'] = csv_file['Suburb'].replace(' ', 'A')
csv_file['Suburb'] = csv_file['Suburb'].replace('A', np.nan)

# %%
# checking the number of null values in the csv file in all the columns
print(csv_file.isnull().sum())
# Out:
# long               0
# lat                0
# Street Number      0
# Road Name          0
# Road Type          0
# LGAName            0
# Suburb           175
# postcode           0
# State              0
# name               0
# dtype: int64

# %%
# filling the null values of suburb column
# groupby postcode, and transform('first') to get rid of nan values:
csv_file['Suburb'] = csv_file.groupby("postcode")["Suburb"].transform("first")

# %%
# filling the remaining missing value of suburb colum  with the matching value of LGAName column
csv_file['Suburb'] = csv_file['Suburb'].fillna(csv_file['LGAName'])

# %%
# checking the number of null values in the csv file in all the columns
print(csv_file.isnull().sum())
# Out:
# long             0
# lat              0
# Street Number    0
# Road Name        0
# Road Type        0
# LGAName          0
# Suburb           0
# postcode         0
# State            0
# name             0
# dtype: int64

# %%
# creating address column by merging street number,roadname,roadtype and suburb
csv_file['address'] = csv_file['Street Number'].fillna('').astype(str) + ',' + csv_file['Road Name'].fillna('').astype(str) + csv_file['Road Type'].fillna('').astype(str)+ ',' + csv_file['Suburb'].fillna('').astype(str)
csv_file['address'] = csv_file['address'].str.strip(',')

# dropping columns
csv_file = csv_file.drop(['Street Number', 'Road Name','Road Type', 'LGAName', 'Suburb','State'], axis=1)

# %%
csv_file['postcode'].dtype
csv_file['lat'].dtype
csv_file['long'].dtype
# Out:
# dtype('float64')

# %%
#Exporting to csv
csv_file.to_csv('hospital_locations_final.csv',index = False)
